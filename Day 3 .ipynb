# %%
### unchangable
tuple = ("math" , "electricity" , "IT")
print(type(tuple))
print(tuple)
# Out:
# <class 'tuple'>
# ('math', 'electricity', 'IT')

# %%
### doesnt allow repeat
set = {"arabic" , "english" , "technology" , "arabic"}
print(set)
# Out:
# {'arabic', 'technology', 'english'}

# %%
dict = {"name": "john" , "school" : "weschool" , "grade" :"2"}
print(dict)
# Out:
# {'name': 'john', 'school': 'weschool', 'grade': '2'}

# %%
print(dict.items())
# Out:
# dict_items([('name', 'john'), ('school', 'weschool'), ('grade', '2')])

# %%
print(dict.keys())
# Out:
# dict_keys(['name', 'school', 'grade'])

# %%
print(dict.values())
# Out:
# dict_values(['john', 'weschool', '2'])

# %%
print(dict['name'])
# Out:
# john

# %%
print(dict['school'])
# Out:
# weschool

# %%
data = {'name':['john','mark','sally'] , 'school':'weschool' , 'grade':'2'}
print(data['name'])
# Out:
# ['john', 'mark', 'sally']

# %%
x = 10
y = 35

if(x > y):
    print("x is greater than y")
elif(x == y):
    print("x is equal y")
else:
    print("x is less than y")
# Out:
# x is less than y

# %%
a = float(input(" Enter number "))

if( a > 0):
    print(" Positive ")
elif( a == 0):
    print(" Zero ")
else:
    print("Negative")
# Out:
#  Enter number  -3
# Negative

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
## while loop
i = 1

while(i < 6):
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5
